# %%
import pandas as pd

# change this to the path of the output of detector_evaluation.py

df = pd.read_csv(r'yoloworld_results_full.csv')

# Filter rows based on column: 'recall'
df = df[df['recall'] > 0.95]

# Filter rows based on column: 'precision'
df = df[df['precision'] > 0.95]

# Sort by column: 'recall' (descending)
df = df.sort_values(['recall'], ascending=[False])

display(df)


# output

# 100	yolov8l-worldv2.pt	['cat', 'dog', 'domestic cat', 'domestic dog', 'sphynx cat', 'bombay cat', 'birman cat', 'tiger', 'big tiger', 'fox', 'wolf', 'coyote', 'drawing', 'painting']	tiger	0.05	0.958041958041958	102	35	5	1	0.9532710280373832	0.9902912621359224	0.9714285714285714
# Out:
#              model_name                                          class_set  \
# 100  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 180  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 181  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 120  yolov8l-worldv2.pt                            ['cat', 'dog', 'tiger']
# 192  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# ..                  ...                                                ...
# 82   yolov8m-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 83   yolov8m-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 195  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 196  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 197  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
#
#     cutoff  confidence_threshold  accuracy  true positive  true negative  \
# 100  tiger                  0.05  0.958042            102             35
# 180  tiger                  0.05  0.958042            101             36
# 181  tiger                  0.10  0.958042            101             36
# 120  tiger                  0.05  0.951049            101             35
# 192  tiger                  0.15  0.951049            101             35
# ..     ...                   ...       ...            ...            ...
# 82   tiger                  0.15  0.937063             98             36
# 83   tiger                  0.20  0.937063             98             36
# 195  tiger                  0.30  0.930070             98             35
# 196  tiger                  0.35  0.937063             98             36
# 197  tiger                  0.40  0.944056             98             37
#
#      false postivie  false negative  precision    recall  f1_score
# 100               5               1   0.953271  0.990291  0.971429
# 180               4               2   0.961905  0.980583  0.971154
# 181               4               2   0.961905  0.980583  0.971154
# 120               5               2   0.952830  0.980583  0.966507
# 192               5               2   0.952830  0.980583  0.966507
# ..              ...             ...        ...       ...       ...
# 82                4               5   0.960784  0.951456  0.956098
# 83                4               5   0.960784  0.951456  0.956098
# 195               5               5   0.951456  0.951456  0.951456
# 196               4               5   0.960784  0.951456  0.956098
# 197               3               5   0.970297  0.951456  0.960784
#
# [84 rows x 12 columns]

# %%
## fine grained from previous step

import pandas as pd

# change this to the path of the output of detector_evaluation.py

df = pd.read_csv(r'yoloworld_results_fine_grained.csv')

# Filter rows based on column: 'recall'
df = df[df['recall'] > 0.95]

# Filter rows based on column: 'precision'
df = df[df['precision'] > 0.95]

# Sort by column: 'recall' (descending)
df = df.sort_values(['recall'], ascending=[False])

display(df)
# Out:
#             model_name                                          class_set  \
# 5   yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 6   yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 7   yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 8   yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 19  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 20  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 50  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 51  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 52  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 54  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 53  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 55  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 56  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 39  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 40  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 41  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 38  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 35  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 36  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 37  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 34  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 58  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 57  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 49  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 60  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 62  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 61  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 42  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 59  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 21  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 22  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 23  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 24  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 25  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 10  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 9   yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 26  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 43  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 28  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 15  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 27  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 13  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 12  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 14  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 11  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 46  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 45  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 44  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 30  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 29  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 31  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 47  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 63  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
#
#    cutoff  confidence_threshold  accuracy  true positive  true negative  \
# 5   tiger                 0.050  0.958042            102             35
# 6   tiger                 0.060  0.958042            102             35
# 7   tiger                 0.070  0.958042            102             35
# 8   tiger                 0.080  0.958042            101             36
# 19  tiger                 0.030  0.958042            101             36
# 20  tiger                 0.040  0.958042            101             36
# 50  tiger                 0.020  0.951049            101             35
# 51  tiger                 0.030  0.958042            101             36
# 52  tiger                 0.040  0.958042            101             36
# 54  tiger                 0.060  0.958042            101             36
# 53  tiger                 0.050  0.958042            101             36
# 55  tiger                 0.070  0.958042            101             36
# 56  tiger                 0.080  0.958042            101             36
# 39  tiger                 0.070  0.958042            101             36
# 40  tiger                 0.080  0.958042            101             36
# 41  tiger                 0.090  0.958042            101             36
# 38  tiger                 0.060  0.958042            101             36
# 35  tiger                 0.030  0.951049            101             35
# 36  tiger                 0.040  0.951049            101             35
# 37  tiger                 0.050  0.958042            101             36
# 34  tiger                 0.020  0.951049            101             35
# 58  tiger                 0.100  0.958042            101             36
# 57  tiger                 0.090  0.958042            101             36
# 49  tiger                 0.010  0.951049            101             35
# 60  tiger                 0.150  0.951049            100             36
# 62  tiger                 0.200  0.951049            100             36
# 61  tiger                 0.175  0.951049            100             36
# 42  tiger                 0.100  0.951049            100             36
# 59  tiger                 0.125  0.951049            100             36
# 21  tiger                 0.050  0.951049            100             36
# 22  tiger                 0.060  0.951049            100             36
# 23  tiger                 0.070  0.951049            100             36
# 24  tiger                 0.080  0.951049            100             36
# 25  tiger                 0.090  0.951049            100             36
# 10  tiger                 0.100  0.951049            100             36
# 9   tiger                 0.090  0.951049            100             36
# 26  tiger                 0.100  0.951049            100             36
# 43  tiger                 0.125  0.951049            100             36
# 28  tiger                 0.150  0.944056             99             36
# 15  tiger                 0.250  0.944056             99             36
# 27  tiger                 0.125  0.944056             99             36
# 13  tiger                 0.175  0.944056             99             36
# 12  tiger                 0.150  0.944056             99             36
# 14  tiger                 0.200  0.944056             99             36
# 11  tiger                 0.125  0.944056             99             36
# 46  tiger                 0.200  0.944056             99             36
# 45  tiger                 0.175  0.944056             99             36
# 44  tiger                 0.150  0.944056             99             36
# 30  tiger                 0.200  0.944056             99             36
# 29  tiger                 0.175  0.944056             99             36
