# %%
import pandas as pd

# change this to the path of the output of detector_evaluation.py
    
df = pd.read_csv(r'results/yoloworld_results_full.csv')

# Filter rows based on column: 'recall'
df = df[df['recall'] > 0.95]

# Filter rows based on column: 'precision'
df = df[df['precision'] > 0.95]

# Sort by column: 'recall' (descending)
df = df.sort_values(['recall'], ascending=[False])

display(df)


# output

# 100	yolov8l-worldv2.pt	['cat', 'dog', 'domestic cat', 'domestic dog', 'sphynx cat', 'bombay cat', 'birman cat', 'tiger', 'big tiger', 'fox', 'wolf', 'coyote', 'drawing', 'painting']	tiger	0.05	0.958041958041958	102	35	5	1	0.9532710280373832	0.9902912621359224	0.9714285714285714
# Out:
#              model_name                                          class_set  \
# 100  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 150  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 161  yolov8x-worldv2.pt                                     ['cat', 'dog']
# 160  yolov8x-worldv2.pt                                     ['cat', 'dog']
# 163  yolov8x-worldv2.pt                                     ['cat', 'dog']
# ..                  ...                                                ...
# 68   yolov8m-worldv2.pt                                     ['cat', 'dog']
# 51   yolov8m-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 195  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 196  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 197  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
#
# ...

# %%
## fine grained from previous step

import pandas as pd

# change this to the path of the output of detector_evaluation.py

df = pd.read_csv(r'results/yoloworld_results_fine_grained.csv')

# Filter rows based on column: 'recall'
df = df[df['recall'] > 0.95]

# Filter rows based on column: 'precision'
df = df[df['precision'] > 0.95]

# Sort by column: 'recall' (descending)
df = df.sort_values(['recall'], ascending=[False])

display(df)
# Out:
#             model_name                                          class_set  \
# 39  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 6   yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 37  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 38  yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 5   yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# ..                 ...                                                ...
# 91  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 92  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 93  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 94  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 95  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
#
#    cutoff  confidence_threshold  accuracy  true positive  true negative  \
# ...

# %%
import pandas as pd

# change this to the path of the output of detector_evaluation.py
    
df = pd.read_csv(r'results/yoloworld_results_full_more_thresholds.csv')

# Filter rows based on column: 'recall'
df = df[df['recall'] > 0.95]

# Filter rows based on column: 'precision'
df = df[df['precision'] > 0.95]

# Sort by column: 'recall' (descending)
df = df.sort_values(['recall'], ascending=[False])

display(df)
# Out:
#              model_name                                          class_set  \
# 85   yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 86   yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 87   yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 7    yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 6    yolov8l-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# ..                  ...                                                ...
# 187  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 188  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 189  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 190  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
# 191  yolov8x-worldv2.pt  ['cat', 'dog', 'domestic cat', 'domestic dog',...
#
# ...
